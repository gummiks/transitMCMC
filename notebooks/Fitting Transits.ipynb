# %%
import everest
import k2help
reload(k2help)

# %matplotlib inline

# %%
star = k2help.EverestGK(201465501)
# Out:
# INFO  [everest.user.DownloadFile()]: Found cached file.
# INFO  [everest.user.load_fits()]: Loading FITS file for 201465501.

# %%
star.plot()
# Out:
# INFO  [everest.user.plot()]: Plotting the light curve...

# %% [markdown]
# ##### Has known planet parameters from Crossfield et al. 2016
#
# <img src="epic_table.png">

# %%
everest.Everest.compute??

# %%
t0  = 1989.6744
t0_err = 0.028
per = 18.4474
per_err = 0.0015
star.mask_planet??#(t0,per)
star.compute()
star.plot_folded(t0,per)
# Out:
# INFO  [everest.basecamp.compute()]: Computing the model...

# %%
star.get_flattened_flux()

# %%
star.get_flattened_flux()

# %%
star.plot_folded2(t0,per)
